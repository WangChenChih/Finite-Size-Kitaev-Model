# %%
import numpy as np
import matplotlib.pyplot as plt
#from scipy import linalg as la
from numpy import linalg as LA
from spin_model_DM import SpinSystem
#from FittingTool import FittingToolLib as ft
import os
import shutil
